# %%
age = 20
height = 5.8
name = "Udit"
is_student = True

print("age: " , age)
print("height: " , height)
print("name: " , name)
print("is_student: " , is_student)
# Out:
# age:  20
# height:  5.8
# name:  Udit
# is_student:  True

# %%
## name and Name are diff
name = "udit"
Name = "bansal"

## Type conversion
print(age)
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# 20
# 20
# <class 'str'>
