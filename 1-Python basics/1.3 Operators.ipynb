# %%
a = 10
b= 5

floor_division = a//b ## Removes the decimal
modulus = a%b
exponent = a**b

print(floor_division)
print(modulus)
print(exponent)
# Out:
# 2
# 0
# 100000

# %%
## Logical Operators

X = True
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
X = True
Y = False

result = X and Y
print(result)
# Out:
# False

# %%
X = True
Y = False

result = X or Y
print(result)
# Out:
# True

# %%
not X
# Out:
# False
