# %%
## if statement
age = 20
if age >= 18:
    print("Adult")
# Out:
# Adult

# %%
age = 16
if age >= 18:
    print("Adult")
else:
    print("Child")
# Out:
# Child

# %%
age = 14
if age<13:
    print("Child")
elif age<=19:
    print("Teenager")
else:
    print("adult")
# Out:
# Teenager
