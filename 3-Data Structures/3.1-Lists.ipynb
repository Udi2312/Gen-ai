# %%
lst = []
print(type(lst))
# Out:
# <class 'list'>

# %%
names = ["Udit" , "Bansal" , 1,2,3,4]
print(names)
# Out:
# ['Udit', 'Bansal', 1, 2, 3, 4]

# %%
### Accessing List elements
fruits = ["apple" , "mango" , "banana" , "kiwi" , "guava"]
print(fruits[0])
print(fruits[2])
print(fruits[4])
print(fruits[-1])
print(fruits[-2])
# Out:
# apple
# banana
# guava
# guava
# kiwi

# %%
print(fruits[1:])
# Out:
# ['mango', 'banana', 'kiwi', 'guava']

# %%
print(fruits[1:3])
# Out:
# ['mango', 'banana']

# %%
### Modifying List elements
fruits[1] = "watermelon"
print(fruits)
# Out:
# ['apple', 'watermelon', 'banana', 'kiwi', 'guava']

# %%
### List methods
# fruits.append("orange")
# print(fruits)

# fruits.insert(2,"cherry")
# print(fruits)

# fruits.remove("cherry")
# print(fruits)

ans = fruits.pop()
print(ans)
print(fruits)
# Out:
# orange
# ['apple', 'watermelon', 'cherry', 'banana', 'kiwi', 'guava', 'orange']
